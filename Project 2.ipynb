# %%
import pandas as pd 
import csv
import http.client, urllib.request, urllib.parse, urllib.error, base64
import numpy as np

#symbols = ['.DJI','.INX','NI225','UKX'] #,'SPE350','SPLAC','000001','DAX','OSPTX','KOSPI','EB1X','SPE350']
symbols = ['UKX']

# URL = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol=INX&apikey=Y442NEI1Q76NWLAR&datatype=csv&outputsize=full'
# responses = urllib.request.urlopen(URL)
# #data = csv.reader(responses)
# data2 = pd.read_csv(responses)
# print(data2)

# %%
data = {}
for market in symbols:
    url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol='+ market +'&apikey=Y442NEI1Q76NWLAR&datatype=csv&outputsize=full'
    response = urllib.request.urlopen(url)
    ind_data = pd.read_csv(response)
    data[market] = ind_data

urlbit = 'https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_DAILY&symbol=BTC&market=CNY&apikey=Y442NEI1Q76NWLAR&datatype=csv'
response = urllib.request.urlopen(urlbit)
bitcoin_data = pd.read_csv(response)
data['bitcoin'] = bitcoin_data

# %%
#print(data['.INX']['timestamp']) #making sure the data is stored as a data frame
print(data)
# Out:
# {'UKX':        timestamp    open    high     low   close  adjusted_close  volume  \
# 0     2016-07-06  654.54  658.03  643.25  646.36          646.36       0
# 1     2016-07-05  652.23  656.16  647.23  654.54          654.54       0
# 2     2016-07-01  650.43  658.74  649.86  657.78          657.78       0
# 3     2016-06-30  636.01  650.43  631.00  650.43          650.43       0
# 4     2016-06-29  614.04  636.01  614.04  636.01          636.01       0
# 5     2016-06-28  598.22  617.03  598.22  614.04          614.04       0
# 6     2016-06-27  613.87  613.87  595.87  598.22          598.22       0
# 7     2016-06-24  633.81  633.86  578.87  613.87          613.87       0
# 8     2016-06-23  626.12  638.06  626.12  633.81          633.81       0
# 9     2016-06-22  622.66  631.56  622.20  626.12          626.12       0
# 10    2016-06-21  620.40  625.02  615.62  622.66          622.66       0
# 11    2016-06-20  602.11  623.65  602.11  620.40          620.40       0
# ...

# %%
for market in symbols:
    data[market].to_csv('/Users/bryandickens/Documents/GitHub/ETL_Project/Bryans_folder/' + market + '.csv', index = False, columns = ['timestamp', 'open', 'high', 'low', 'close'])
    
#data['bitcoinAA'].to_csv('/Users/bryandickens/Documents/GitHub/ETL_Project/Bryans_folder/', index = False, columns = ['timestamp', 'open (USD)', 'high (USD)', 'low (USD)', 'close (USD)'], header = ['timestamp', 'open', 'high', 'low', 'close'])

#data['bitcoincd'][:-2].to_csv('/Users/bryandickens/Documents/GitHub/ETL_Project/Bryans_folder/bitcoincd.csv', columns = ['bpi'], header = ['bpi'], index_label = 'timestamp')
