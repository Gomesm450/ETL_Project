# %%
import pandas as pd
from pandas.io.json import json_normalize
import requests
import urllib3
import json

dest_path = 'Users/bryandickens/Documents/GitHub/HW-Dump/Project2_csvs'

# %%
url = 'https://api.coindesk.com/v1/bpi/historical/close.json?start=2012-01-01&end=2018-10-20'

# %%
response = requests.get(url).json()
# snp_response = requests.get(snp_url).json()
# euro_snp_response = requests.get(euro_snp_url).json()
# la_snp_response = requests.get(la_snp_url).json()
# chn_response = requests.get(chn_url).json()
# nikkei_response = requests.get(nikkei_url).json()
# germ_response = requests.get(germ_url).json()
# ftse_response = requests.get(ftse_url).json()
# euro_ftse_response = requests.get(euro_ftse_url).json()

# %%
response
# Out:
# {'bpi': {'2012-01-01': 5.2677,
#   '2012-01-02': 5.2168,
#   '2012-01-03': 4.8808,
#   '2012-01-04': 5.5738,
#   '2012-01-05': 6.9476,
#   '2012-01-06': 6.6969,
#   '2012-01-07': 6.81,
#   '2012-01-08': 7.1136,
#   '2012-01-09': 6.3257,
#   '2012-01-10': 6.36,
#   '2012-01-11': 6.9,
#   '2012-01-12': 6.8,
#   '2012-01-13': 6.41,
#   '2012-01-14': 6.75,
#   '2012-01-15': 7.0018,
#   '2012-01-16': 6.6825,
#   '2012-01-17': 5.6,
#   '2012-01-18': 5.92,
#   '2012-01-19': 6.3598,
#   '2012-01-20': 6.4898,
#   '2012-01-21': 6.18,
#   '2012-01-22': 6.3097,
#   '2012-01-23': 6.356,
#   '2012-01-24': 6.2898,
#   '2012-01-25': 5.75,
#   '2012-01-26': 5.34,
#   '2012-01-27': 5.292,
#   '2012-01-28': 5.6267,
#   '2012-01-29': 5.3809,
#   '2012-01-30': 5.4905,
#   '2012-01-31': 5.4838,
#   '2012-02-01': 6.0756,
#   '2012-02-02': 6.1,
#   '2012-02-03': 5.9593,
#   '2012-02-04': 5.8734,
#   '2012-02-05': 5.6888,
#   '2012-02-06': 5.4535,
#   '2012-02-07': 5.69,
#   '2012-02-08': 5.6,
# ...

# %%
api_key = 'Y442NEI1Q76NWLAR'
base_url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol='
api_url = '&apikey='
dtype = '&datatype=json'
